# %%
import pandas as pd
biomass_df = pd.read_csv(r"C:\Users\imaja\OneDrive\Desktop\MBA 2022 -2024\T6\Capstone\Datasets\train+test.csv")

# %%
biomass_df
# Out:
#       Index  Latitude  Longitude       2010       2011       2012       2013  \
# 0         0  24.66818   71.33144   8.475744   8.868568   9.202181   6.023070
# 1         1  24.66818   71.41106  24.029778  28.551348  25.866415  21.634459
# 2         2  24.66818   71.49069  44.831635  66.111168  56.982258  53.003735
# 3         3  24.66818   71.57031  59.974419  80.821304  78.956543  63.160561
# 4         4  24.66818   71.64994  14.653370  19.327524  21.928144  17.899586
# ...     ...       ...        ...        ...        ...        ...        ...
# 2413   2413  20.15456   72.84432   5.199882   4.516778   4.321080   2.658953
# 2414   2414  20.15456   72.92394   0.122287   0.126717   0.101494   0.111509
# 2415   2415  20.15456   73.00357   0.039415   0.040843   0.032713   0.035941
# 2416   2416  20.15456   73.08319   2.719220   1.370163   0.818687   1.205721
# 2417   2417  20.15456   73.16282   0.621228   0.238414   0.112909   0.209801
#
# ...

# %%
import pandas as pd

# Assuming your data is stored in a DataFrame called 'df'
# If not, you can create one using pd.DataFrame(your_data)

# Set 'Index' as the index and transpose the DataFrame
transposed_df = biomass_df.set_index('Index').transpose()

# Reset the index to have 'Year' as a column
transposed_df = transposed_df.reset_index().rename(columns={'index': 'Year'})
# Out:
# Index       Year          0          1          2           3          4  \
# 0       Latitude  24.668180  24.668180  24.668180   24.668180  24.668180
# 1      Longitude  71.331440  71.411060  71.490690   71.570310  71.649940
# 2           2010   8.475744  24.029778  44.831635   59.974419  14.653370
# 3           2011   8.868568  28.551348  66.111168   80.821304  19.327524
# 4           2012   9.202181  25.866415  56.982258   78.956543  21.928144
# 5           2013   6.023070  21.634459  53.003735   63.160561  17.899586
# 6           2014  10.788374  34.419411  70.917908   93.513924  19.534035
# 7           2015   6.647325  27.361908  42.517117   70.203171  19.165791
# 8           2016   7.387925  40.431847  59.181629   74.536720  16.531315
# 9           2017   5.180296  42.126945  73.203232  101.067352  26.086885
# 10          2018   7.119092  45.937351  75.666054   94.867676  18.417318
# 11          2019  10.704760  26.978222  56.543396   65.010101  24.765160
#
# ...

# %%
# Drop the first two rows
transposed_df = transposed_df.iloc[2:]

# %%
transposed_df
# Out:
# Index  Year          0          1          2           3          4  \
# 2      2010   8.475744  24.029778  44.831635   59.974419  14.653370
# 3      2011   8.868568  28.551348  66.111168   80.821304  19.327524
# 4      2012   9.202181  25.866415  56.982258   78.956543  21.928144
# 5      2013   6.023070  21.634459  53.003735   63.160561  17.899586
# 6      2014  10.788374  34.419411  70.917908   93.513924  19.534035
# 7      2015   6.647325  27.361908  42.517117   70.203171  19.165791
# 8      2016   7.387925  40.431847  59.181629   74.536720  16.531315
# 9      2017   5.180296  42.126945  73.203232  101.067352  26.086885
# 10     2018   7.119092  45.937351  75.666054   94.867676  18.417318
# 11     2019  10.704760  26.978222  56.543396   65.010101  24.765160
#
# Index          5          6          7          8  ...       2408      2409  \
# 2      17.416639  23.568657  48.345234  58.784283  ...  13.863707  7.931598
# ...

# %%
# Drop the first two rows
transposed_df = transposed_df.iloc[2:]

# %%
#export

transposed_df.to_csv(r"C:\Users\imaja\OneDrive\Desktop\MBA 2022 -2024\T6\Capstone\Datasets\transposed.csv", index=False)
